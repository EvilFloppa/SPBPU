# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Графики-зависимостей" data-toc-modified-id="Графики-зависимостей-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Графики зависимостей</a></div><div class="lev1 toc-item"><a href="#Круговые-графики" data-toc-modified-id="Круговые-графики-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Круговые графики</a></div><div class="lev1 toc-item"><a href="#Точечные-диаграммы" data-toc-modified-id="Точечные-диаграммы-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Точечные диаграммы</a></div><div class="lev1 toc-item"><a href="#Гистограммы" data-toc-modified-id="Гистограммы-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Гистограммы</a></div><div class="lev1 toc-item"><a href="#Подграфики" data-toc-modified-id="Подграфики-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Подграфики</a></div><div class="lev1 toc-item"><a href="#Зачем-это-нужно?" data-toc-modified-id="Зачем-это-нужно?-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Зачем это нужно?</a></div>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Графики зависимостей
# plt.plot(x, y)

# %%
x = np.linspace(0, 20, 500)
y1 = np.sin(x)
y2 = np.sin(x - np.pi)

plt.figure()

plt.plot(x, y1)
plt.plot(x, y2)

# %% [markdown]
# * `color`: Цвет линии
#
# * `linestyle`: способ соединения точек: толстая линия, прерывистая, её отсутствие
#
# * `linewidth`: Задаем тонкость линии
#
# * `marker`: Что использовать для обозначения точки(круг, квадрат,треугольник, ничего).
#
# * `markersize`: Очевидно.
#
# * `label`: Название для данного графика в легенде.

# %%
x = np.linspace(0, 20, 10000)
y1 = np.sin(x)
y2 = np.sin(x - np.pi)

plt.figure()

plt.plot(x, y1, color='gray', linestyle='-', marker='s', markersize=2, label='sinx')
plt.plot(x, y2, color='green', linestyle='--', marker='^', markersize=5, label='sin(x-pi)')
plt.legend()

# %% [markdown]
# plt.bar(left, height)
#
# * `left`: x координата
#
# * `height`: соответствующая высота столбца

# %%
years = np.arange(2012, 2015)
values = [2, 5, 9]
plt.figure()
plt.bar(years, values)
plt.a
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# * `color`: Цвет столба
#
# * `edgecolor`: Цвет края столба
#
# * `width`: Ширина столбика
#
# * `label`: аналогично как с plot

# %%
years = np.arange(2012, 2015)
category1_values = [2, 5, 9]
category2_values = [7, 6, 3]

plt.figure()

plt.bar(years - 0.2,
        category1_values,
        color='blue',
        edgecolor='none',
        width=0.4,
        align='center',
        label='y1')

plt.bar(years + 0.2,
        category2_values,
        color='orange',
        edgecolor='blue',
        width=0.4,
        align='center',
        label='y2')

plt.xticks(years, [str(year) for year in years])

plt.legend()

# %% [markdown]
# # Круговые графики
#
#
# plt.pie(sizes)
#
# * `sizes`:

# %%
counts = [17, 14]

plt.figure(figsize=(5,5))

plt.pie(counts)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e909635438>,
#   <matplotlib.patches.Wedge at 0x1e909635898>],
#  [Text(-0.1665706012300369, 1.0873151497178102, ''),
#   Text(0.16657060123003722, -1.0873151497178102, '')])

# %%
counts = [17, 3]

plt.figure(figsize=(4, 4))

plt.pie(counts,
        colors=['blue', 'orange'],
        labels=['Cats', 'Dogs'],
        startangle=90,
        autopct='%1.1f%%')
;
# Out:
# ''

# %% [markdown]
# # Точечные диаграммы
#
# plt.scatter(x,y)

# %%
x = range(20)
y = np.arange(50, 70) + (np.random.random(20) * 10.)

plt.figure()

plt.scatter(x, y)

# %% [markdown]
# Многие функции данной библиотеки имеют похожие параметры.

# %%
x = np.arange(20)
y = np.arange(50, 70) + (np.random.random(20) * 10.)

plt.figure()

plt.scatter(x, y, c='red',
            marker='s',
            edgecolor='blue')

# %% [markdown]
# # Гистограммы
#
# plt.hist(x)
# `x`: Массив для которого мы хотим посмотреть распределение

# %%
column_data = np.random.normal(42, 3, 1000000)

plt.figure()

plt.hist(column_data)
# Out:
# (array([4.60000e+01, 1.64300e+03, 2.19240e+04, 1.26640e+05, 3.15804e+05,
#         3.40309e+05, 1.58842e+05, 3.19900e+04, 2.71800e+03, 8.40000e+01]),
#  array([27.47827839, 30.33156347, 33.18484855, 36.03813363, 38.89141871,
#         41.74470379, 44.59798887, 47.45127395, 50.30455903, 53.15784411,
#         56.01112919]),
#  <a list of 10 Patch objects>)

# %%
column_data = np.random.normal(42, 3, 10000)

plt.figure()

plt.hist(column_data,color='red',
         bins=50,
         normed=True)
# Out:
# (array([0.0002048 , 0.        , 0.00040959, 0.00040959, 0.0002048 ,
#         0.00122878, 0.00143357, 0.00225276, 0.00327674, 0.00614388,
#         0.00839664, 0.01208297, 0.01433573, 0.01884125, 0.0372729 ,
#         0.0428024 , 0.05427098, 0.07147386, 0.07864172, 0.08580959,
#         0.10690359, 0.11570983, 0.12369688, 0.12656402, 0.12390167,
#         0.13004556, 0.12861199, 0.12001055, 0.11304748, 0.10014532,
#         0.0903151 , 0.07720815, 0.06123405, 0.05263261, 0.03911607,
#         0.02887626, 0.02437074, 0.01392614, 0.0108542 , 0.00778225,
#         0.00593909, 0.00348153, 0.00163837, 0.00122878, 0.        ,
#         0.0002048 , 0.00081918, 0.        , 0.        , 0.0002048 ]),
#  array([29.86094152, 30.34923194, 30.83752235, 31.32581277, 31.81410318,
#         32.3023936 , 32.79068401, 33.27897443, 33.76726484, 34.25555526,
#         34.74384567, 35.23213609, 35.7204265 , 36.20871692, 36.69700733,
#         37.18529775, 37.67358816, 38.16187858, 38.65016899, 39.13845941,
#         39.62674982, 40.11504024, 40.60333065, 41.09162107, 41.57991148,
#         42.0682019 , 42.55649231, 43.04478273, 43.53307314, 44.02136356,
#         44.50965397, 44.99794439, 45.4862348 , 45.97452522, 46.46281563,
#         46.95110605, 47.43939646, 47.92768688, 48.41597729, 48.90426771,
#         49.39255812, 49.88084854, 50.36913895, 50.85742937, 51.34571978,
#         51.83401019, 52.32230061, 52.81059102, 53.29888144, 53.78717185,
#         54.27546227]),
#  <a list of 50 Patch objects>)

# %% [markdown]
# # Подграфики
#
# Позволяет вам строить несколько отдельных графиков на одном изображении.
#
# subplot(nrows, ncols, plot_number)
#
# * `nrows`: Количество графиков в ряд по вертикали
#
# * `ncols`: Количество графиков в ряд по горизонтали
#
# * `plot_number`: Расположение графика на изображении, отсчет начинается с 1.

# %%
plt.figure()

for i in range(1, 7):
    plt.subplot(3, 2, i)
    plt.title(i)
    plt.xticks([])
    plt.yticks([])

plt.tight_layout()

# %% [markdown]
# # Зачем это нужно?

# %%
years = np.arange(2010, 2016)

plt.figure()

for category_num in range(1, 17):
    y_vals = np.arange(10, 16) + (np.random.random(6) * category_num / 4.)
    plt.plot(years, y_vals)

plt.ylim(10, 18)
plt.xticks(years, [str(year) for year in years])
# Out:
# ([<matplotlib.axis.XTick at 0x1e90a1344e0>,
#   <matplotlib.axis.XTick at 0x1e90b27d860>,
#   <matplotlib.axis.XTick at 0x1e90b2238d0>,
#   <matplotlib.axis.XTick at 0x1e90b223cf8>,
#   <matplotlib.axis.XTick at 0x1e90b254630>,
#   <matplotlib.axis.XTick at 0x1e90b2237b8>],
#  <a list of 6 Text xticklabel objects>)

# %%
years = np.arange(2010, 2016)

plt.figure(figsize=(10, 10))

for category_num in range(1, 17):
    plt.subplot(4, 4, category_num)
    y_vals = np.arange(10, 16) + (np.random.random(6) * category_num / 4.)
    plt.plot(years, y_vals)
    plt.ylim(10, 18)
    plt.xticks(years, [str(year) for year in years])
    plt.title('Number {}'.format(category_num))
    
plt.tight_layout()
